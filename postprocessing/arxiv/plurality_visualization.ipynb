# %%
# %matplotlib inline
# %pylab inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('parallel_merge_plurality.csv', names=['k','node','number_influenced','s'])

# %%
df
# Out:
#         k   node  number_influenced   s
# 0       0  24587                  1   0
# 1       0  24587                  2   1
# 2       0  24587                 26   2
# 3       1  24587                 41   2
# 4       2  24587                 42   2
# 5       0  24587                145   3
# 6       1  24587                204   3
# 7       2  24587                206   3
# 8       0  24587                730   4
# 9       1  24587                994   4
# 10      2  24587               1018   4
# 11      3  24587               1037   4
# 12      4  24587               1043   4
# 13      5  24587               1047   4
# 14      6  24587               1050   4
# 15      7  24587               1054   4
# 16      0  24587               2028   5
# 17      1  24587               2497   5
# 18      2  24587               2557   5
# 19      3  24587               2580   5
# 20      4  24587               2592   5
# 21      5  24587               2596   5
# 22      0  24587               3371   6
# 23      1  24587               3608   6
# 24      2  24587               3623   6
# 25      3  24587               3628   6
# 26      4  24587               3631   6
# 27      5  24587               3632   6
# 28      0  24587               3940   7
# 29      1  24587               4010   7
# ...    ..    ...                ...  ..
# 165976  2  24506               1032   5
# 165977  3  24506               1038   5
# 165978  4  24506               1049   5
# 165979  5  24506               1051   5
# 165980  6  24506               1054   5
# 165981  7  24506               1055   5
# 165982  0  24506               1950   6
# 165983  1  24506               2388   6
# 165984  2  24506               2454   6
# 165985  3  24506               2480   6
# 165986  4  24506               2487   6
# 165987  5  24506               2496   6
# 165988  0  24506               3322   7
# 165989  1  24506               3582   7
# 165990  2  24506               3594   7
# 165991  3  24506               3598   7
# 165992  4  24506               3600   7
# 165993  0  24506               3939   8
# 165994  1  24506               4009   8
# 165995  2  24506               4012   8
# 165996  3  24506               4013   8
# 165997  4  24506               4014   8
# 165998  5  24506               4015   8
# 165999  0  24506               4100   9
# 166000  1  24506               4118   9
# 166001  0  24506               4139  10
# 166002  1  24506               4144  10
# 166003  0  24506               4153  11
# 166004  1  24506               4156  11
# 166005  0  24506               4158  12
#
# [166006 rows x 4 columns]

# %%
df.groupby(['node','s'], sort=False)['k'].max()
idx = df.groupby(['node','s'])['k'].transform(max) == df['k']

# %%
df_sub_sample = df[idx][['node','number_influenced','s']]

# %%
df_sub_sample = df_sub_sample.reset_index(drop=True)
df_sub_sample.head()
# Out:
#     node  number_influenced  s
# 0  24587                  1  0
# 1  24587                  2  1
# 2  24587                 42  2
# 3  24587                206  3
# 4  24587               1054  4

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_sub_sample['node'],
           df_sub_sample['s'],
           df_sub_sample['number_influenced'],
           cmap=plt.cm.viridis,
           c='skyblue', s=6)

ax.set_xlabel('node', fontsize=15)
ax.set_ylabel('s', fontsize=15)
ax.set_zlabel('number_influenced', fontsize=15)

ax.view_init(30, -40)

plt.show()

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_sub_sample['node'],
           df_sub_sample['s'],
           df_sub_sample['number_influenced'],
           linewidth=0, s=6, c=df_sub_sample['number_influenced'],  cmap=cm.coolwarm)

ax.set_xlabel('node', fontsize=15)
ax.set_ylabel('s', fontsize=15)
ax.set_zlabel('number_influenced', fontsize=15)

ax.view_init(30, -40)

plt.show()

# %%
count_s = df_sub_sample[['s','node']].groupby(['s'], as_index=False).count().sort_values(by=['s'])
count_s
# Out:
#      s  node
# 0    0  4158
# 1    1  4158
# 2    2  4158
# 3    3  4158
# 4    4  4158
# 5    5  4158
# 6    6  4158
# 7    7  4158
# 8    8  4158
# 9    9  4158
# 10  10  4145
# 11  11  3683
# 12  12  2207
# 13  13   778
# 14  14   207
# 15  15    66
# 16  16    29
# 17  17     8

# %%
y_second_label = []
y_second_label.append('')
for r in count_s['node']:
    y_second_label.append('n = {}'.format(r))
    
len(y_second_label)
# Out:
# 19

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13

fig, ax = plt.subplots(figsize=(20,10))
sc = ax.scatter(df_sub_sample['node'], df_sub_sample['s'],
           c=df_sub_sample['number_influenced'],
           cmap=cm.coolwarm, s=100, marker='|')

yint = range(0, 20)
matplotlib.pyplot.yticks(yint)

ax.set_xlabel('nodes', fontsize=15)
ax.set_ylabel('bootstrap neighbors', fontsize=16)


plt.title('Linear Threshold Rank: arxiv - simple-majority', fontsize=15)


cbar = plt.colorbar(sc, pad=0.1)
cbar.ax.set_ylabel('Nodes influenced', rotation=90,  labelpad=-90, fontsize=13)


ax2 = ax.twinx()
ax2.set_yticks(range(0, 20))
ax2.set_yticklabels(y_second_label)


plt.show()
