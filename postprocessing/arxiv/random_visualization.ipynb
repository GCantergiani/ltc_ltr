# %%
# %matplotlib inline
# %pylab inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('parallel_merge_random.csv', names=['k','node','number_influenced','s'])

# %%
df
# Out:
#          k   node  number_influenced   s
# 0        0  24587                  1   0
# 1        0  24587                  2   1
# 2        1  24587                 14   1
# 3        2  24587                 56   1
# 4        3  24587                230   1
# 5        4  24587                680   1
# 6        5  24587               1603   1
# 7        6  24587               2508   1
# 8        7  24587               3097   1
# 9        8  24587               3359   1
# 10       9  24587               3463   1
# 11      10  24587               3510   1
# 12      11  24587               3521   1
# 13      12  24587               3524   1
# 14       0  24587                 26   2
# 15       1  24587                 93   2
# 16       2  24587                345   2
# 17       3  24587                967   2
# 18       4  24587               1966   2
# 19       5  24587               2753   2
# 20       6  24587               3214   2
# 21       7  24587               3419   2
# 22       8  24587               3488   2
# 23       9  24587               3518   2
# 24      10  24587               3522   2
# 25      11  24587               3524   2
# 26       0  24587                145   3
# 27       1  24587                499   3
# 28       2  24587               1211   3
# 29       3  24587               2230   3
# ...     ..    ...                ...  ..
# 380882   5  24559               3511   3
# 380883   6  24559               3547   3
# 380884   7  24559               3560   3
# 380885   8  24559               3561   3
# 380886   9  24559               3562   3
# 380887   0  24559               2067   4
# 380888   1  24559               2921   4
# 380889   2  24559               3422   4
# 380890   3  24559               3597   4
# 380891   4  24559               3663   4
# 380892   5  24559               3686   4
# 380893   6  24559               3696   4
# 380894   0  24559               3359   5
# 380895   1  24559               3706   5
# 380896   2  24559               3854   5
# 380897   3  24559               3893   5
# 380898   4  24559               3907   5
# 380899   5  24559               3910   5
# 380900   0  24559               3935   6
# 380901   1  24559               4018   6
# 380902   2  24559               4061   6
# 380903   3  24559               4072   6
# 380904   0  24559               4087   7
# 380905   1  24559               4114   7
# 380906   2  24559               4126   7
# 380907   0  24559               4145   8
# 380908   1  24559               4154   8
# 380909   0  24559               4157   9
# 380910   1  24559               4158   9
# 380911   0  24559               4158  10
#
# [380912 rows x 4 columns]

# %%
df.groupby(['node','s'], sort=False)['k'].max()
idx = df.groupby(['node','s'])['k'].transform(max) == df['k']

# %%
df_sub_sample = df[idx][['node','number_influenced','s']]

# %%
df_sub_sample = df_sub_sample.reset_index(drop=True)
df_sub_sample.head()
# Out:
#     node  number_influenced  s
# 0  24587                  1  0
# 1  24587               3524  1
# 2  24587               3524  2
# 3  24587               3532  3
# 4  24587               3567  4

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_sub_sample['node'],
           df_sub_sample['s'],
           df_sub_sample['number_influenced'],
           cmap=plt.cm.viridis,
           c='skyblue', s=6)

ax.set_xlabel('node', fontsize=15)
ax.set_ylabel('s', fontsize=15)
ax.set_zlabel('number_influenced', fontsize=15)

ax.view_init(30, -40)

plt.show()

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_sub_sample['node'],
           df_sub_sample['s'],
           df_sub_sample['number_influenced'],
           linewidth=0, s=6, c=df_sub_sample['number_influenced'],  cmap=cm.coolwarm)

ax.set_xlabel('node', fontsize=15)
ax.set_ylabel('s', fontsize=15)
ax.set_zlabel('number_influenced', fontsize=15)

ax.view_init(30, -40)

plt.show()

# %%
count_s = df_sub_sample[['s','node']].groupby(['s'], as_index=False).count().sort_values(by=['s'])
count_s
# Out:
#      s  node
# 0    0  4158
# 1    1  4158
# 2    2  4158
# 3    3  4158
# 4    4  4158
# 5    5  4158
# 6    6  4158
# 7    7  4158
# 8    8  4158
# 9    9  4158
# 10  10  4145
# 11  11  3683
# 12  12  2207
# 13  13   778
# 14  14   207
# 15  15    66
# 16  16    29
# 17  17     8

# %%
y_second_label = []
y_second_label.append('')
for r in count_s['node']:
    y_second_label.append('n = {}'.format(r))
    
len(y_second_label)
# Out:
# 19

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13

fig, ax = plt.subplots(figsize=(20,10))
sc = ax.scatter(df_sub_sample['node'], df_sub_sample['s'],
           c=df_sub_sample['number_influenced'],
           cmap=cm.coolwarm, s=100, marker='|')

yint = range(0, 20)
matplotlib.pyplot.yticks(yint)

ax.set_xlabel('nodes', fontsize=15)
ax.set_ylabel('bootstrap neighbors', fontsize=16)


plt.title('Linear Threshold Rank: arxiv - random', fontsize=15)


cbar = plt.colorbar(sc, pad=0.1)
cbar.ax.set_ylabel('Nodes influenced', rotation=90,  labelpad=-90, fontsize=13)


ax2 = ax.twinx()
ax2.set_yticks(range(0, 20))
ax2.set_yticklabels(y_second_label)


plt.show()
