# %%
# %matplotlib inline
# %pylab inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('parallel_merge_min.csv', names=['k','node','number_influenced','s'])

# %%
df
# Out:
#          k   node  number_influenced   s
# 0        0  24589                  1   0
# 1        1  24589                  5   0
# 2        2  24589                 23   0
# 3        3  24589                 97   0
# 4        4  24589                451   0
# 5        5  24589               1553   0
# 6        6  24589               2962   0
# 7        7  24589               3799   0
# 8        8  24589               4068   0
# 9        9  24589               4126   0
# 10      10  24589               4149   0
# 11      11  24589               4158   0
# 12       0  24589                  5   1
# 13       1  24589                 23   1
# 14       2  24589                 97   1
# 15       3  24589                451   1
# 16       4  24589               1553   1
# 17       5  24589               2962   1
# 18       6  24589               3799   1
# 19       7  24589               4068   1
# 20       8  24589               4126   1
# 21       9  24589               4149   1
# 22      10  24589               4158   1
# 23       0  24589                 23   2
# 24       1  24589                 97   2
# 25       2  24589                451   2
# 26       3  24589               1553   2
# 27       4  24589               2962   2
# 28       5  24589               3799   2
# 29       6  24589               4068   2
# ...     ..    ...                ...  ..
# 362832   6   8118               4151   6
# 362833   7   8118               4158   6
# 362834   0   8118               1706   7
# 362835   1   8118               3131   7
# 362836   2   8118               3877   7
# 362837   3   8118               4079   7
# 362838   4   8118               4128   7
# 362839   5   8118               4151   7
# 362840   6   8118               4158   7
# 362841   0   8118               3131   8
# 362842   1   8118               3877   8
# 362843   2   8118               4079   8
# 362844   3   8118               4128   8
# 362845   4   8118               4151   8
# 362846   5   8118               4158   8
# 362847   0   8118               3877   9
# 362848   1   8118               4079   9
# 362849   2   8118               4128   9
# 362850   3   8118               4151   9
# 362851   4   8118               4158   9
# 362852   0   8118               4079  10
# 362853   1   8118               4128  10
# 362854   2   8118               4151  10
# 362855   3   8118               4158  10
# 362856   0   8118               4128  11
# 362857   1   8118               4151  11
# 362858   2   8118               4158  11
# 362859   0   8118               4151  12
# 362860   1   8118               4158  12
# 362861   0   8118               4158  13
#
# [362862 rows x 4 columns]

# %%
df.groupby(['node','s'], sort=False)['k'].max()
idx = df.groupby(['node','s'])['k'].transform(max) == df['k']

# %%
df_sub_sample = df[idx][['node','number_influenced','s']]

# %%
df_sub_sample = df_sub_sample.reset_index(drop=True)
df_sub_sample.head()
# Out:
#     node  number_influenced  s
# 0  24589               4158  0
# 1  24589               4158  1
# 2  24589               4158  2
# 3  24589               4158  3
# 4  24589               4158  4

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_sub_sample['node'],
           df_sub_sample['s'],
           df_sub_sample['number_influenced'],
           cmap=plt.cm.viridis,
           c='skyblue', s=6)

ax.set_xlabel('node', fontsize=15)
ax.set_ylabel('s', fontsize=15)
ax.set_zlabel('number_influenced', fontsize=15)

ax.view_init(30, -40)

plt.show()

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_sub_sample['node'],
           df_sub_sample['s'],
           df_sub_sample['number_influenced'],
           linewidth=0, s=6, c=df_sub_sample['number_influenced'],  cmap=cm.coolwarm)

ax.set_xlabel('node', fontsize=15)
ax.set_ylabel('s', fontsize=15)
ax.set_zlabel('number_influenced', fontsize=15)

ax.view_init(30, -40)

plt.show()

# %%
count_s = df_sub_sample[['s','node']].groupby(['s'], as_index=False).count().sort_values(by=['s'])
count_s
# Out:
#      s  node
# 0    0  4158
# 1    1  4158
# 2    2  4158
# 3    3  4158
# 4    4  4158
# 5    5  4158
# 6    6  4158
# 7    7  4158
# 8    8  4158
# 9    9  4158
# 10  10  4145
# 11  11  3683
# 12  12  2207
# 13  13   778
# 14  14   207
# 15  15    66
# 16  16    29
# 17  17     8

# %%
y_second_label = []
y_second_label.append('')
for r in count_s['node']:
    y_second_label.append('n = {}'.format(r))
    
len(y_second_label)
# Out:
# 19

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13

fig, ax = plt.subplots(figsize=(20,10))
sc = ax.scatter(df_sub_sample['node'], df_sub_sample['s'],
           c=df_sub_sample['number_influenced'],
           cmap=cm.coolwarm, s=100, marker='|', norm=mpl.colors.Normalize(vmin=-0.5, vmax=4200))

yint = range(0, 20)
matplotlib.pyplot.yticks(yint)

ax.set_xlabel('nodes', fontsize=15)
ax.set_ylabel('bootstrap neighbors', fontsize=16)


plt.title('Linear Threshold Rank: arxiv - min', fontsize=15)


cbar = plt.colorbar(sc, pad=0.1)
cbar.ax.set_ylabel('Nodes influenced', rotation=90,  labelpad=-90, fontsize=13)


ax2 = ax.twinx()
ax2.set_yticks(range(0, 20))
ax2.set_yticklabels(y_second_label)


plt.show()
