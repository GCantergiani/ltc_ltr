# %%
import pandas as pd
import networkx as nx

from collections import OrderedDict
from tqdm import tqdm
from IPython.display import Image

# %% [markdown]
# ## Graph

# %% [markdown]
# ![title](./graph.png)

# %% [markdown]
# ## Read network file

# %%
df = pd.read_csv('network.csv')
df
# Out:
#     source  target  weight
# 0        1       2       2
# 1        1       4       3
# 2        2       1       1
# 3        2       6       1
# 4        3       2       1
# 5        3       6       2
# 6        4       5       1
# 7        5       4       4
# 8        5       6       2
# 9        5       9       2
# 10       5       7       1
# 11       7       1       1
# 12       8       5       1
# 13       8       9       2
# 14       9       6       1

# %% [markdown]
# ## Generate graph

# %%
def generate_graph(df):
    """
    Generate two directed graph
    :param df: A df with source, target, timestamp columns,
               the tuple source, target is not unique, so for each
               occurrence we update the weight attribute
    :return: The main graph (G1), a the reverse one (G2)
    
    """

    # Create first directed graph
    G1 = nx.DiGraph()
    for row in df.itertuples():
        G1.add_edge(row.source, row.target, weight=row.weight)
            

    # Create second directed graph
    G2 = nx.DiGraph()
    for row in df.itertuples():
        G2.add_edge(row.target, row.source, weight=row.weight)
        
    return G1, G2

# %% [markdown]
# ## Plurality Attr

# %%
def add_plurality_attribute(G1, G2, nodes):
    """
    Add plurality attribute.
    """
    for n in nodes:
        
        if(G1.degree(n) == 0):
            plurality = sys.maxsize
        else:
            sum_weight = 0
            for g2_node_source in G2.neighbors(n):
                sum_weight = sum_weight + G1.get_edge_data(g2_node_source, n)['weight']

            plurality = int(sum_weight/2) + 1
            
        G1.node[n]['plurality'] = plurality
        print('Node {} plurality {}'.format(n, plurality))
    return G1

# %%
g1, g2 = generate_graph(df)

# %%
unique_nodes = set()
unique_nodes.update(df['source'].unique())
unique_nodes.update(df['target'].unique())
len(unique_nodes)
# Out:
# 9

# %%
g1 = add_plurality_attribute(g1, g2, unique_nodes)
# Out:
# Node 1 plurality 2
# Node 2 plurality 2
# Node 3 plurality 1
# Node 4 plurality 4
# Node 5 plurality 2
# Node 6 plurality 4
# Node 7 plurality 1
# Node 8 plurality 1
# Node 9 plurality 3

# %%
def get_neighborhood(node, g1, g2, total_nodes):
    """
    Calculate nodes according at the neighborhood level.
    Using a node as bootstrap:
    - The first level is only the node, 
    - The second level is the first node and their neighbors
    - The third level .... 
    
    :param node: The boostrap node identifier
    :param g1: Main graph
    :param g2: Reverse graph
    :param total_nodes: Number of unique nodes in the main graph
    :return: A list with the initial node, the neighborhood level,
             and their nodes
    """
    old_nodes = set()
    new_nodes = set()
    
    neighborhood = []
    neighborhood.append({'inital_node':node,
                         's': 0, 
                         'nodes':[node]})

    new_nodes.add(node)
    last_nodes = None

    for idx, n in enumerate(range(total_nodes)):

        nodes_to_add = set()
        for new_node in new_nodes:
            nodes_to_add.update(g1.neighbors(new_node))
            nodes_to_add.update(g2.neighbors(new_node))

        old_nodes= old_nodes.union(new_nodes)

        new_nodes.clear()
        new_nodes.update(nodes_to_add)


        nodes_s_level = set(old_nodes).union(new_nodes)

        neighborhood.append({'inital_node':node,
                             's':idx + 1, 
                             'nodes':nodes_s_level})

        if len(nodes_s_level) == total_nodes:
            return neighborhood

# %%
def linear_threshold_rank(node, G1, G2, total_nodes):
    """
    Calculate the lTR for each node 
    - https://www.sciencedirect.com/science/article/pii/S0950705117304975
    """
    linear_threshold_rank = []
    
    PRINT_STEPS = True

    if PRINT_STEPS:
        print('-------------- Node: {} --------------'.format(node))
              
    neighborhoods = get_neighborhood(node, g1, g2, total_nodes)
    
    for neighborhood in neighborhoods:

        first_step = True

        nodes_to_add_group = set()

        # Get first neighbors (bootstrap nodes)
        neighbors = set()
        
        for bootstrap_node in neighborhood['nodes']:
            neighbors.add(bootstrap_node)
            neighbors.update(G1.neighbors(bootstrap_node))
            neighbors.update(G2.neighbors(bootstrap_node))

        group = set()
        group.update(neighbors)

        if PRINT_STEPS:
            print('I: 0 ; Neighbors: {0} ; count: {1}'.format(neighbors, len(neighbors)))

        depth_level = 0

        while( first_step or (len(nodes_to_add_group) >= 1) ):

            first_step = False

            neighbors.update(nodes_to_add_group)
            group.update(nodes_to_add_group)

            nodes_to_add_group.clear()

            if PRINT_STEPS:
                print('\t group: {1}'.format(node, group))

            next_nodes = set()
            for next_node in neighbors:
                next_nodes.update(G1.neighbors(next_node))

            # Nodes that can be influenced
            dispersion = set()
            dispersion = next_nodes - group

            if PRINT_STEPS:
                print('\t dispersion {0} '.format(dispersion))

            # For each dispersion node
            for n_sub_level in dispersion:
                plurality = G1.node[n_sub_level]['plurality']

                if PRINT_STEPS:
                    print('\t \t Reach node {0} | plurality {1}'.format(n_sub_level, plurality))

                group_influce = 0
                for node_group in group:
                    if(G1.get_edge_data(node_group, n_sub_level)):
                        group_influce = group_influce + G1.get_edge_data(node_group,n_sub_level)['weight']

                if PRINT_STEPS:
                    print('\t \t group {0} | influce {1}'.format(group, group_influce))

                if(group_influce >= plurality):
                    nodes_to_add_group.add(n_sub_level)

            if PRINT_STEPS:
                print('\t \t \t new group {0} '.format(nodes_to_add_group))
                print('{0} ; {1} ; {2}'.format(node, depth_level, len(group)))
                print()
                
                
            linear_threshold_rank.append({'node':node,
                                          'k':depth_level,
                                          'group_influenced':group.copy(),
                                          'number_influenced':len(group),
                                          's':neighborhood['s']})
            
            depth_level = depth_level +1 
        
    return linear_threshold_rank

# %%
# %%time
results = []
for node in unique_nodes:
    results.extend(linear_threshold_rank(node, g1, g2, len(unique_nodes)))
# Out:
# -------------- Node: 1 --------------
# I: 0 ; Neighbors: {1, 2, 4, 7} ; count: 4
# 	 group: {1, 2, 4, 7}
# 	 dispersion {5, 6}
# 	 	 Reach node 5 | plurality 2
# 	 	 group {1, 2, 4, 7} | influce 1
# 	 	 Reach node 6 | plurality 4
# 	 	 group {1, 2, 4, 7} | influce 1
# 	 	 	 new group set()
# 1 ; 0 ; 4
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7} ; count: 7
# 	 group: {1, 2, 3, 4, 5, 6, 7}
# 	 dispersion {9}
# 	 	 Reach node 9 | plurality 3
# 	 	 group {1, 2, 3, 4, 5, 6, 7} | influce 2
# 	 	 	 new group set()
# 1 ; 0 ; 7
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 1 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 1 ; 0 ; 9
#
# -------------- Node: 2 --------------
# I: 0 ; Neighbors: {1, 2, 3, 6} ; count: 4
# 	 group: {1, 2, 3, 6}
# 	 dispersion {4}
# 	 	 Reach node 4 | plurality 4
# 	 	 group {1, 2, 3, 6} | influce 3
# 	 	 	 new group set()
# 2 ; 0 ; 4
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 9} ; count: 8
# 	 group: {1, 2, 3, 4, 5, 6, 7, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 2 ; 0 ; 8
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 2 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 2 ; 0 ; 9
#
# -------------- Node: 3 --------------
# I: 0 ; Neighbors: {2, 3, 6} ; count: 3
# 	 group: {2, 3, 6}
# 	 dispersion {1}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {2, 3, 6} | influce 1
# 	 	 	 new group set()
# 3 ; 0 ; 3
#
# I: 0 ; Neighbors: {1, 2, 3, 5, 6, 9} ; count: 6
# 	 group: {1, 2, 3, 5, 6, 9}
# 	 dispersion {4, 7}
# 	 	 Reach node 4 | plurality 4
# 	 	 group {1, 2, 3, 5, 6, 9} | influce 7
# 	 	 Reach node 7 | plurality 1
# 	 	 group {1, 2, 3, 5, 6, 9} | influce 1
# 	 	 	 new group {4, 7}
# 3 ; 0 ; 6
#
# 	 group: {1, 2, 3, 4, 5, 6, 7, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 3 ; 1 ; 8
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 3 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 3 ; 0 ; 9
#
# -------------- Node: 4 --------------
# I: 0 ; Neighbors: {1, 4, 5} ; count: 3
# 	 group: {1, 4, 5}
# 	 dispersion {9, 2, 6, 7}
# 	 	 Reach node 9 | plurality 3
# 	 	 group {1, 4, 5} | influce 2
# 	 	 Reach node 2 | plurality 2
# 	 	 group {1, 4, 5} | influce 2
# 	 	 Reach node 6 | plurality 4
# 	 	 group {1, 4, 5} | influce 2
# 	 	 Reach node 7 | plurality 1
# 	 	 group {1, 4, 5} | influce 1
# 	 	 	 new group {2, 7}
# 4 ; 0 ; 3
#
# 	 group: {1, 2, 4, 5, 7}
# 	 dispersion {9, 6}
# 	 	 Reach node 9 | plurality 3
# 	 	 group {1, 2, 4, 5, 7} | influce 2
# 	 	 Reach node 6 | plurality 4
# 	 	 group {1, 2, 4, 5, 7} | influce 3
# 	 	 	 new group set()
# 4 ; 1 ; 5
#
# I: 0 ; Neighbors: {1, 2, 4, 5, 6, 7, 8, 9} ; count: 8
# 	 group: {1, 2, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 4 ; 0 ; 8
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 4 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 4 ; 0 ; 9
#
# -------------- Node: 5 --------------
# I: 0 ; Neighbors: {4, 5, 6, 7, 8, 9} ; count: 6
# 	 group: {4, 5, 6, 7, 8, 9}
# 	 dispersion {1}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {4, 5, 6, 7, 8, 9} | influce 1
# 	 	 	 new group set()
# 5 ; 0 ; 6
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 5 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 5 ; 0 ; 9
#
# -------------- Node: 6 --------------
# I: 0 ; Neighbors: {9, 2, 3, 5, 6} ; count: 5
# 	 group: {9, 2, 3, 5, 6}
# 	 dispersion {1, 4, 7}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {9, 2, 3, 5, 6} | influce 1
# 	 	 Reach node 4 | plurality 4
# 	 	 group {9, 2, 3, 5, 6} | influce 4
# 	 	 Reach node 7 | plurality 1
# 	 	 group {9, 2, 3, 5, 6} | influce 1
# 	 	 	 new group {4, 7}
# 6 ; 0 ; 5
#
# 	 group: {2, 3, 4, 5, 6, 7, 9}
# 	 dispersion {1}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {2, 3, 4, 5, 6, 7, 9} | influce 2
# 	 	 	 new group {1}
# 6 ; 1 ; 7
#
# 	 group: {1, 2, 3, 4, 5, 6, 7, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 6 ; 2 ; 8
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 6 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 6 ; 0 ; 9
#
# -------------- Node: 7 --------------
# I: 0 ; Neighbors: {1, 5, 7} ; count: 3
# 	 group: {1, 5, 7}
# 	 dispersion {9, 2, 4, 6}
# 	 	 Reach node 9 | plurality 3
# 	 	 group {1, 5, 7} | influce 2
# 	 	 Reach node 2 | plurality 2
# 	 	 group {1, 5, 7} | influce 2
# 	 	 Reach node 4 | plurality 4
# 	 	 group {1, 5, 7} | influce 7
# 	 	 Reach node 6 | plurality 4
# 	 	 group {1, 5, 7} | influce 2
# 	 	 	 new group {2, 4}
# 7 ; 0 ; 3
#
# 	 group: {1, 2, 4, 5, 7}
# 	 dispersion {9, 6}
# 	 	 Reach node 9 | plurality 3
# 	 	 group {1, 2, 4, 5, 7} | influce 2
# 	 	 Reach node 6 | plurality 4
# 	 	 group {1, 2, 4, 5, 7} | influce 3
# 	 	 	 new group set()
# 7 ; 1 ; 5
#
# I: 0 ; Neighbors: {1, 2, 4, 5, 6, 7, 8, 9} ; count: 8
# 	 group: {1, 2, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 7 ; 0 ; 8
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 7 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 7 ; 0 ; 9
#
# -------------- Node: 8 --------------
# I: 0 ; Neighbors: {8, 9, 5} ; count: 3
# 	 group: {8, 9, 5}
# 	 dispersion {4, 6, 7}
# 	 	 Reach node 4 | plurality 4
# 	 	 group {8, 9, 5} | influce 4
# 	 	 Reach node 6 | plurality 4
# 	 	 group {8, 9, 5} | influce 3
# 	 	 Reach node 7 | plurality 1
# 	 	 group {8, 9, 5} | influce 1
# 	 	 	 new group {4, 7}
# 8 ; 0 ; 3
#
# 	 group: {8, 9, 4, 5, 7}
# 	 dispersion {1, 6}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {8, 9, 4, 5, 7} | influce 1
# 	 	 Reach node 6 | plurality 4
# 	 	 group {8, 9, 4, 5, 7} | influce 3
# 	 	 	 new group set()
# 8 ; 1 ; 5
#
# I: 0 ; Neighbors: {4, 5, 6, 7, 8, 9} ; count: 6
# 	 group: {4, 5, 6, 7, 8, 9}
# 	 dispersion {1}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {4, 5, 6, 7, 8, 9} | influce 1
# 	 	 	 new group set()
# 8 ; 0 ; 6
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 8 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 8 ; 0 ; 9
#
# -------------- Node: 9 --------------
# I: 0 ; Neighbors: {8, 9, 5, 6} ; count: 4
# 	 group: {8, 9, 5, 6}
# 	 dispersion {4, 7}
# 	 	 Reach node 4 | plurality 4
# 	 	 group {8, 9, 5, 6} | influce 4
# 	 	 Reach node 7 | plurality 1
# 	 	 group {8, 9, 5, 6} | influce 1
# 	 	 	 new group {4, 7}
# 9 ; 0 ; 4
#
# 	 group: {4, 5, 6, 7, 8, 9}
# 	 dispersion {1}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {4, 5, 6, 7, 8, 9} | influce 1
# 	 	 	 new group set()
# 9 ; 1 ; 6
#
# I: 0 ; Neighbors: {2, 3, 4, 5, 6, 7, 8, 9} ; count: 8
# 	 group: {2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion {1}
# 	 	 Reach node 1 | plurality 2
# 	 	 group {2, 3, 4, 5, 6, 7, 8, 9} | influce 2
# 	 	 	 new group {1}
# 9 ; 0 ; 8
#
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 9 ; 1 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 9 ; 0 ; 9
#
# I: 0 ; Neighbors: {1, 2, 3, 4, 5, 6, 7, 8, 9} ; count: 9
# 	 group: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 	 dispersion set()
# 	 	 	 new group set()
# 9 ; 0 ; 9
#
# CPU times: user 36 ms, sys: 8 ms, total: 44 ms
# Wall time: 36.5 ms

# %%
df_results = pd.DataFrame(results)
df_results[['node','s','k','number_influenced','group_influenced']].sort_values(by=['node','s','k'])
# Out:
#     node  s  k  number_influenced             group_influenced
# 0      1  0  0                  4                 {1, 2, 4, 7}
# 1      1  1  0                  7        {1, 2, 3, 4, 5, 6, 7}
# 2      1  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 3      1  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 4      2  0  0                  4                 {1, 2, 3, 6}
# 5      2  1  0                  8     {1, 2, 3, 4, 5, 6, 7, 9}
# 6      2  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 7      2  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 8      3  0  0                  3                    {2, 3, 6}
# 9      3  1  0                  6           {1, 2, 3, 5, 6, 9}
# 10     3  1  1                  8     {1, 2, 3, 4, 5, 6, 7, 9}
# 11     3  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 12     3  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 13     4  0  0                  3                    {1, 4, 5}
# 14     4  0  1                  5              {1, 2, 4, 5, 7}
# 15     4  1  0                  8     {1, 2, 4, 5, 6, 7, 8, 9}
# 16     4  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 17     4  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 18     5  0  0                  6           {4, 5, 6, 7, 8, 9}
# 19     5  1  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 20     5  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 21     6  0  0                  5              {9, 2, 3, 5, 6}
# 22     6  0  1                  7        {2, 3, 4, 5, 6, 7, 9}
# 23     6  0  2                  8     {1, 2, 3, 4, 5, 6, 7, 9}
# 24     6  1  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 25     6  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 26     7  0  0                  3                    {1, 5, 7}
# 27     7  0  1                  5              {1, 2, 4, 5, 7}
# 28     7  1  0                  8     {1, 2, 4, 5, 6, 7, 8, 9}
# 29     7  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 30     7  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 31     8  0  0                  3                    {8, 9, 5}
# 32     8  0  1                  5              {8, 9, 4, 5, 7}
# 33     8  1  0                  6           {4, 5, 6, 7, 8, 9}
# 34     8  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 35     8  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 36     9  0  0                  4                 {8, 9, 5, 6}
# 37     9  0  1                  6           {4, 5, 6, 7, 8, 9}
# 38     9  1  0                  8     {2, 3, 4, 5, 6, 7, 8, 9}
# 39     9  1  1                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 40     9  2  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
# 41     9  3  0                  9  {1, 2, 3, 4, 5, 6, 7, 8, 9}
